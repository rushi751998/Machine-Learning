# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(('https://raw.githubusercontent.com/rushi751998/test2/main/Backtest.csv'))
data.head()
# Out:
#    Unnamed: 0    Symbol Buy/Sell  Entry Price  Entry Date  Exit Price  \
# 0           0  Reliance      Buy      1259.14  2019-08-23     1206.19
# 1           1  Reliance     Sell      1206.19  2019-09-09     1279.82
# 2           2       Upl      Buy       596.70  2019-09-30      529.13
# 3           3       Upl     Sell       529.13  2019-11-14      582.28
# 4           4  Reliance      Buy      1279.82  2019-09-26     1493.33
#
#     Exit Date  Per trade return  Probability  Return  Drawdowm
# 0  2019-09-09             -1.05          0.0   -1.05     -1.05
# 1  2019-09-26             -1.53          0.0   -2.58     -2.58
# 2  2019-11-14             -2.83          0.0   -5.41     -5.41
# 3  2019-12-30             -2.51          0.0   -7.92     -7.92
# 4  2020-01-08              4.17         20.0   -3.75     -3.75

# %%
data_filterd = (data[(data['Probability']>50) & (data['Drawdowm'] <-3 )][['Symbol',"Drawdowm"]])
# data_filterd.sort_values(by="Drawdowm",ascending=True,inplace=True)
data_filterd
# Out:
#         Symbol  Drawdowm
# 18   Tatasteel     -3.44
# 19  Tatamotors     -7.98
# 20         Upl     -6.83
# 21    Reliance     -7.70
# 22    Reliance     -9.77

# %%
plt.plot(data_filterd['Symbol'],data_filterd['Drawdowm'])
plt.show()

# %%
data.head()
# Out:
#    Unnamed: 0    Symbol Buy/Sell  Entry Price  Entry Date  Exit Price  \
# 0           0  Reliance      Buy      1259.14  2019-08-23     1206.19
# 1           1  Reliance     Sell      1206.19  2019-09-09     1279.82
# 2           2       Upl      Buy       596.70  2019-09-30      529.13
# 3           3       Upl     Sell       529.13  2019-11-14      582.28
# 4           4  Reliance      Buy      1279.82  2019-09-26     1493.33
#
#     Exit Date  Per trade return  Probability  Return  Drawdowm
# 0  2019-09-09             -1.05          0.0   -1.05     -1.05
# 1  2019-09-26             -1.53          0.0   -2.58     -2.58
# 2  2019-11-14             -2.83          0.0   -5.41     -5.41
# 3  2019-12-30             -2.51          0.0   -7.92     -7.92
# 4  2020-01-08              4.17         20.0   -3.75     -3.75

# %%
data.groupby("Symbol")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 data[data.groupby("Symbol")]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:6105, in Index._get_indexer_strict(self, key, axis_name)
#    6103 keyarr = key
#    6104 if not isinstance(keyarr, Index):
# -> 6105     keyarr = com.asarray_tuplesafe(keyarr)
#    6107 if self._index_as_unique:
#    6108     indexer = self.get_indexer_for(keyarr)
#
# ...
